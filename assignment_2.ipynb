# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 1.Read the dataset

# %%
data = pd.read_csv('cars_data.csv')

# %%
data
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # 2.Check for the null values

# %%
data.isnull().sum()
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # 3.bar graph of male vs female buyers

# %%
data.columns
# Out:
# Index(['Make', 'Model', 'Nickname', 'Car Gender', 'Buyer Gender', 'Buyer Age',
#        'Buzzword', 'Country', 'City', 'Dealer Latitude', 'Dealer Longitude',
#        'Color', 'New Car', 'Purchase Date', 'Sale Price', 'Discount',
#        'Resell Price', '5-yr Depreciation', 'Top Speed', '0-60 Time'],
#       dtype='object')

# %%
data['Buyer Gender'].value_counts()
# Out:
# Female    5052
# Male      4948
# Name: Buyer Gender, dtype: int64

# %%
x=['Female','Male']
y=data['Buyer Gender'].value_counts()
plt.bar(x,y,0.3)
plt.title('bar graph of male vs female buyers')
plt.grid()
plt.show()

# %% [markdown]
# # 4.Top 5 cars based on their sales price.

# %%
data['rank by sales price']=data['Sale Price'].rank(ascending=False)

# %%
data.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  ...    Color  \
# 0  User-friendly   Belgium        Antwerpen        51.247239  ...   Yellow
# 1      analyzing     China            Jinhu        33.025433  ...  Crimson
# 2       software     China             Gemo        30.916207  ...    Khaki
# 3     monitoring  Portugal  Queluz de Baixo        38.745168  ...     Puce
# 4       Sharable    Latvia         Jaunpils        56.729980  ...   Yellow
#
#   New Car  Purchase Date Sale Price  Discount  Resell Price  \
# ...

# %%
data.sort_values('Sale Price',ascending=False).head()
# Out:
#             Make      Model   Nickname Car Gender Buyer Gender  Buyer Age  \
# 5984  Volkswagen  Jetta III    Rachael     Female       Female         73
# 1270        Audi         A6      Thorn       Male         Male         75
# 3460       Lexus         LX      Aldin     Female         Male         38
# 9032       Mazda       MX-6  Sylvester     Female         Male         26
# 302        Lexus         ES       Brig     Female         Male         39
#
#                Buzzword   Country           City  Dealer Latitude  ...  \
# 5984               core    Russia    Krasnoyarka        59.418208  ...
# 1270           function    Latvia        Līgatne        57.236340  ...
# 3460           software  Malaysia      Pasir Mas         6.109065  ...
# 9032  internet solution    Russia  Krutaya Gorka        55.369917  ...
# 302         user-facing    Canada       Langford        48.447463  ...
#
#        Color New Car  Purchase Date Sale Price  Discount  Resell Price  \
# ...

# %% [markdown]
# # 5.Least 5 cars based on their Resell price.

# %%
data['rank by resell price']=data['Resell Price'].rank(ascending=True)

# %%
data.head()
# Out:
#      Make    Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0  Suzuki   Vitara  Philippine     Female       Female         51
# 1   Honda    S2000      Henrik       Male         Male         30
# 2     BMW       Z4      Lebbie       Male       Female         54
# 3  Toyota   Tacoma    Jefferey     Female         Male         68
# 4    Ford  Festiva     Glendon     Female         Male         70
#
#         Buzzword   Country             City  Dealer Latitude  ...  New Car  \
# 0  User-friendly   Belgium        Antwerpen        51.247239  ...    False
# 1      analyzing     China            Jinhu        33.025433  ...    False
# 2       software     China             Gemo        30.916207  ...    False
# 3     monitoring  Portugal  Queluz de Baixo        38.745168  ...    False
# 4       Sharable    Latvia         Jaunpils        56.729980  ...    False
#
#   Purchase Date  Sale Price Discount  Resell Price  5-yr Depreciation  \
# ...

# %%
data.sort_values('Resell Price',ascending=False).head()
# Out:
#            Make           Model Nickname Car Gender Buyer Gender  Buyer Age  \
# 3224  Chevrolet          Camaro   Durand     Female         Male         50
# 8406       Ford  Econoline E350      Ree     Female       Female         49
# 222       Acura              TL    Zelma       Male       Female         42
# 2512        GMC     Sierra 2500     Neal     Female         Male         64
# 5173  Chevrolet          Blazer     Cari     Female       Female         64
#
#                       Buzzword      Country      City  Dealer Latitude  ...  \
# 3224  Graphical User Interface  Philippines    Teresa        14.570454  ...
# 8406                    Robust  Philippines      Suyo        16.875970  ...
# 222                    Virtual      Ukraine  Radekhiv        50.283692  ...
# 2512               parallelism        China  Pengdian        31.528572  ...
# 5173                motivating        China   Fuchang        37.868872  ...
#
# ...
